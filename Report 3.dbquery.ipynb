-- %%
CREATE OR REPLACE TABLE default.olist_order_items
USING DELTA
AS SELECT *
FROM read_files(
  '/Volumes/workspace/default/sales/olist_order_items_dataset.csv',
  format => 'csv', header => true, inferSchema => true
);
SELECT COUNT(*) AS total_rows FROM default.olist_order_items;
