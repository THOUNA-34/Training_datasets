-- %%
CREATE OR REPLACE TABLE default.olist_customers
USING DELTA
AS SELECT *
FROM read_files(
  '/Volumes/workspace/default/sales/olist_customers_dataset.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

SELECT COUNT(*) AS total_rows 
FROM default.olist_customers;
