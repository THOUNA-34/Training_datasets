-- %%
SELECT * FROM workspace.default.vw_monthly_revenue ORDER BY month;
USE CATALOG workspace;
USE SCHEMA default;

SELECT * FROM workspace.default.vw_delivery_performance;

SELECT * FROM workspace.default.vw_seller_scorecard ORDER BY avg_rating DESC LIMIT 10;
-- Out:
-- Databricks visualization. Run in Databricks to view.
-- Databricks visualization. Run in Databricks to view.
-- Databricks visualization. Run in Databricks to view.
