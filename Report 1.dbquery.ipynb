-- %%
CREATE OR REPLACE TABLE default.olist_orders
USING DELTA
AS SELECT *
FROM read_files(
  '/Volumes/workspace/default/sales/olist_orders_dataset.csv',
  format => 'csv',
  header => true,
  inferSchema => true
);

SELECT COUNT(*) AS total_rows 
FROM default.olist_orders;
