-- %%
COMMENT ON TABLE default.olist_orders
  IS 'Raw orders table — 99,441 orders from Olist Brazilian e-commerce platform (2016-2018)';
COMMENT ON TABLE default.olist_reviews
  IS 'Customer review scores (1-5) and text comments linked to order_id';
COMMENT ON TABLE default.olist_payments
  IS 'Payment records — type (credit_card, boleto, voucher) and value per order';
ALTER TABLE default.olist_orders
  ALTER COLUMN order_status COMMENT 'Values: delivered, shipped, canceled, processing, invoiced, approved, unavailable';

ALTER TABLE default.olist_reviews
  ALTER COLUMN review_score COMMENT 'Integer 1-5. 5 = best. Used as primary satisfaction KPI across all analyses';
